# %%
import requests
from config import api_key
headers = {
    "authorization": api_key,
    "content-type": "application/json"
}

# %%
endpoint = "https://api.assemblyai.com/v2/transcript"
json = {
    "audio_url": "https://bit.ly/3rBnQ8i",
    "sentiment_analysis": True
}
response = requests.post(endpoint, json=json, headers=headers)
transcription_id = response.json().get('id')

# %%
transaction_id = 'oqx6sby2ly-8750-4d8a-8e06-ff4fb0c14390'
end_point = f"https://api.assemblyai.com/v2/transcript/{transaction_id}"
res = requests.get(end_point, headers=headers)
res.json()
# Out:
# {'id': 'oqx6sby2ly-8750-4d8a-8e06-ff4fb0c14390',
#  'language_model': 'assemblyai_default',
#  'acoustic_model': 'assemblyai_default',
#  'language_code': 'en_us',
#  'status': 'completed',
#  'audio_url': 'https://bit.ly/3rBnQ8i',
#  'text': "Ted talks are recorded live at the Ted Conference. This episode features psychologist and happiness expert Dan Gilbert. This talk contains powerful visuals. Download the video@ted.com Dan Gilbert when you have 21 minutes to speak 2 million years seems like a really long time, but evolutionarily 2 million years is nothing. And yet, in 2 million years, the human brain has nearly tripled in mass, going from the one and a quarter pound brain of our ancestor here habilis to the almost three pound meatloaf that everybody here has between their ears. What is it about a big brain that nature was so eager for everyone else to have one? Well, it turns out when brains triple in size, they don't just get three times bigger. They gain new structures. And one of the main reasons that our brain got so big is because it got a new part called the frontal lobe and particularly a part called the prefrontal cortex. And what does the prefrontal cortex do for you that should justify the entire architectural overhaul of the human skull in the blink of evolutionary time? Well, turns out the prefrontal cortex does lots of things, but one of the most important things it does is it is an experience simulator pilots practice in flight simulators so that they don't make real mistakes in planes. Human beings have this marvelous adaptation that they can actually have experiences in their heads before they try them out in real life. This is a trick that none of our ancestors could do, that no other animal can do quite like we can. It's a marvelous adaptation. It's up there with opposable thumbs and standing upright in language as one of the things that got our species out of the trees and into the shopping mall. Now, all of you have done this. I mean, Ben and Jerry's doesn't have liver in onion ice cream, and it's not because they whipped some up, tried it and went Yuck. It's because without leaving your armchair, you can simulate that flavor and say Yuck before you make it. Let's see how your experience simulators are working. Let's just run a quick diagnostic before I PROCEED with the rest of the talk. Here's two different futures that I invite you to contemplate, and you can try to simulate them and tell me which one you think you might prefer. One of them is winning the lottery. This is about $314,000,000, and the other is becoming paraplegic. So just give it a moment of thought. You probably don't feel like you need a moment of thought. And Interestingly, there are data on these two groups of people, data on how happy they are. And this is exactly what you expected, isn't it? But these aren't the data. I made these up. These are the data you failed the pop quiz, and you're hardly five minutes into the lecture because the fact is that a year after losing the use of their legs and a year after winning the Lotto. Lottery winners and paraplegics are equally happy with their lives. Now, don't feel too bad about failing the first pop quiz, because everybody fails all of the pop quizzes all of the time. The research that my laboratory has been doing that economists and psychologists around the country have been doing have revealed something really quite startling to us, something we call the impact bias, which is the tendency for the simulator to work badly for the simulator to make you believe that different outcomes are more different than, in fact, they really are. From field studies to laboratory studies, we see that winning or losing an election, gaining or losing a romantic partner, getting or not getting a promotion, passing or not passing a College test, on and on have far less impact, less intensity, and much less duration than people expect them to have now. In fact, a recent study this almost floors me. A recent study showing how major life traumas affects people suggest that if it happened over three months ago, with only a few exceptions, it has no impact whatsoever on your happiness. Why? Because happiness can be synthesized. Sir Thomas ...
#  'words': [{'text': 'Ted',
#    'start': 8590,
#    'end': 8782,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'talks',
#    'start': 8806,
#    'end': 9142,
#    'confidence': 0.97785,
#    'speaker': None},
#   {'text': 'are',
#    'start': 9166,
#    'end': 9282,
#    'confidence': 0.99086,
#    'speaker': None},
#   {'text': 'recorded',
#    'start': 9296,
#    'end': 9582,
#    'confidence': 0.99953,
#    'speaker': None},
#   {'text': 'live',
#    'start': 9656,
#    'end': 9894,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'at',
#    'start': 9932,
#    'end': 10026,
#    'confidence': 0.93,
#    'speaker': None},
#   {'text': 'the',
#    'start': 10028,
#    'end': 10122,
#    'confidence': 0.57,
#    'speaker': None},
#   {'text': 'Ted',
#    'start': 10136,
#    'end': 10378,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'Conference.',
#    'start': 10414,
#    'end': 10966,
#    'confidence': 0.64598,
#    'speaker': None},
#   {'text': 'This',
#    'start': 11038,
#    'end': 11274,
#    'confidence': 0.99867,
#    'speaker': None},
#   {'text': 'episode',
#    'start': 11312,
#    'end': 11710,
#    'confidence': 0.99152,
#    'speaker': None},
#   {'text': 'features',
#    'start': 11770,
#    'end': 12118,
#    'confidence': 0.86142,
#    'speaker': None},
#   {'text': 'psychologist',
#    'start': 12154,
#    'end': 12778,
#    'confidence': 0.47671,
#    'speaker': None},
#   {'text': 'and',
#    'start': 12814,
#    'end': 12978,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'happiness',
#    'start': 13004,
#    'end': 13366,
#    'confidence': 0.99932,
#    'speaker': None},
#   {'text': 'expert',
#    'start': 13438,
#    'end': 14110,
#    'confidence': 0.99667,
#    'speaker': None},
#   {'text': 'Dan',
#    'start': 14230,
#    'end': 14590,
#    'confidence': 0.82708,
#    'speaker': None},
#   {'text': 'Gilbert.',
#    'start': 14650,
#    'end': 15646,
#    'confidence': 0.99525,
#    'speaker': None},
#   {'text': 'This',
#    'start': 15838,
#    'end': 16158,
#    'confidence': 0.97314,
#    'speaker': None},
#   {'text': 'talk',
#    'start': 16184,
#    'end': 16374,
#    'confidence': 0.99935,
#    'speaker': None},
#   {'text': 'contains',
#    'start': 16412,
#    'end': 16738,
#    'confidence': 0.84192,
#    'speaker': None},
#   {'text': 'powerful',
#    'start': 16774,
#    'end': 17134,
#    'confidence': 0.99649,
#    'speaker': None},
#   {'text': 'visuals.',
#    'start': 17182,
#    'end': 17746,
#    'confidence': 0.99524,
#    'speaker': None},
#   {'text': 'Download',
#    'start': 17818,
#    'end': 18178,
#    'confidence': 0.99971,
#    'speaker': None},
#   {'text': 'the',
#    'start': 18214,
#    'end': 18342,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'video@ted.com',
#    'start': 18356,
#    'end': 19940,
#    'confidence': 0.97,
#    'speaker': None},
#   {'text': 'Dan',
#    'start': 20690,
#    'end': 21130,
#    'confidence': 0.6782,
#    'speaker': None},
#   {'text': 'Gilbert',
#    'start': 21190,
#    'end': 22050,
#    'confidence': 0.84426,
#    'speaker': None},
#   {'text': 'when',
#    'start': 25410,
#    'end': 25738,
#    'confidence': 0.99694,
#    'speaker': None},
#   {'text': 'you',
#    'start': 25764,
#    'end': 25846,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'have',
#    'start': 25848,
#    'end': 25978,
#    'confidence': 0.97366,
#    'speaker': None},
#   {'text': '21',
#    'start': 26004,
#    'end': 26458,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'minutes',
#    'start': 26484,
#    'end': 26710,
#    'confidence': 0.9891,
#    'speaker': None},
#   {'text': 'to',
#    'start': 26760,
#    'end': 26974,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'speak',
#    'start': 27012,
#    'end': 27394,
#    'confidence': 0.99957,
#    'speaker': None},
#   {'text': '2',
#    'start': 27492,
#    'end': 27718,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'million',
#    'start': 27744,
#    'end': 28006,
#    'confidence': 0.98,
#    'speaker': None},
#   {'text': 'years',
#    'start': 28068,
#    'end': 28330,
#    'confidence': 0.99798,
#    'speaker': None},
#   {'text': 'seems',
#    'start': 28380,
#    'end': 28594,
#    'confidence': 0.99069,
#    'speaker': None},
#   {'text': 'like',
#    'start': 28632,
#    'end': 28798,
#    'confidence': 0.99807,
#    'speaker': None},
#   {'text': 'a',
#    'start': 28824,
#    'end': 28942,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'really',
#    'start': 28956,
#    'end': 29206,
#    'confidence': 0.74094,
#    'speaker': None},
#   {'text': 'long',
#    'start': 29268,
#    'end': 29566,
#    'confidence': 0.99921,
#    'speaker': None},
#   {'text': 'time,',
#    'start': 29628,
#    'end': 30214,
#    'confidence': 0.99987,
#    'speaker': None},
#   {'text': 'but',
#    'start': 30372,
#    'end': 30730,
#    'confidence': 0.78403,
#    'speaker': None},
#   {'text': 'evolutionarily',
#    'start': 30780,
#    'end': 31706,
#    'confidence': 0.93543,
#    'speaker': None},
#   {'text': '2',
#    'start': 31778,
#    'end': 31978,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'million',
#    'start': 32004,
#    'end': 32230,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'years',
#    'start': 32280,
#    'end': 32494,
#    'confidence': 0.50632,
#    'speaker': None},
#   {'text': 'is',
#    'start': 32532,
#    'end': 32734,
#    'confidence': 0.67775,
#    'speaker': None},
#   {'text': 'nothing.',
#    'start': 32772,
#    'end': 33010,
#    'confidence': 0.99872,
#    'speaker': None},
#   {'text': 'And',
#    'start': 33060,
#    'end': 33202,
#    'confidence': 0.84,
#    'speaker': None},
#   {'text': 'yet,',
#    'start': 33216,
#    'end': 33358,
#    'confidence': 0.99957,
#    'speaker': None},
#   {'text': 'in',
#    'start': 33384,
#    'end': 33502,
#    'confidence': 0.99766,
#    'speaker': None},
#   {'text': '2',
#    'start': 33516,
#    'end': 33694,
#    'confidence': 0.59,
#    'speaker': None},
#   {'text': 'million',
#    'start': 33732,
#    'end': 34006,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'years,',
#    'start': 34068,
#    'end': 34690,
#    'confidence': 0.99982,
#    'speaker': None},
#   {'text': 'the',
#    'start': 34860,
#    'end': 35158,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'human',
#    'start': 35184,
#    'end': 35446,
#    'confidence': 0.9999,
#    'speaker': None},
#   {'text': 'brain',
#    'start': 35508,
#    'end': 35966,
#    'confidence': 0.99565,
#    'speaker': None},
#   {'text': 'has',
#    'start': 36038,
#    'end': 36274,
#    'confidence': 0.99843,
#    'speaker': None},
#   {'text': 'nearly',
#    'start': 36312,
#    'end': 36710,
#    'confidence': 0.99203,
#    'speaker': None},
#   {'text': 'tripled',
#    'start': 36770,
#    'end': 37502,
#    'confidence': 0.99589,
#    'speaker': None},
#   {'text': 'in',
#    'start': 37646,
#    'end': 38062,
#    'confidence': 0.852,
#    'speaker': None},
#   {'text': 'mass,',
#    'start': 38136,
#    'end': 38626,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'going',
#    'start': 38748,
#    'end': 39034,
#    'confidence': 0.99733,
#    'speaker': None},
#   {'text': 'from',
#    'start': 39072,
#    'end': 39202,
#    'confidence': 0.99962,
#    'speaker': None},
#   {'text': 'the',
#    'start': 39216,
#    'end': 39358,
#    'confidence': 0.95,
#    'speaker': None},
#   {'text': 'one',
#    'start': 39384,
#    'end': 39502,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'and',
#    'start': 39516,
#    'end': 39622,
#    'confidence': 0.9,
#    'speaker': None},
#   {'text': 'a',
#    'start': 39636,
#    'end': 39742,
#    'confidence': 0.93,
#    'speaker': None},
#   {'text': 'quarter',
#    'start': 39756,
#    'end': 40058,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'pound',
#    'start': 40094,
#    'end': 40442,
#    'confidence': 0.89,
#    'speaker': None},
#   {'text': 'brain',
#    'start': 40526,
#    'end': 40838,
#    'confidence': 0.99792,
#    'speaker': None},
#   {'text': 'of',
#    'start': 40874,
#    'end': 41002,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'our',
#    'start': 41016,
#    'end': 41338,
#    'confidence': 0.99889,
#    'speaker': None},
#   {'text': 'ancestor',
#    'start': 41424,
#    'end': 42002,
#    'confidence': 0.82299,
#    'speaker': None},
#   {'text': 'here',
#    'start': 42026,
#    'end': 42214,
#    'confidence': 0.98371,
#    'speaker': None},
#   {'text': 'habilis',
#    'start': 42252,
#    'end': 42902,
#    'confidence': 0.4293,
#    'speaker': None},
#   {'text': 'to',
#    'start': 42986,
#    'end': 43162,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'the',
#    'start': 43176,
#    'end': 43318,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'almost',
#    'start': 43344,
#    'end': 43678,
#    'confidence': 0.99902,
#    'speaker': None},
#   {'text': 'three',
#    'start': 43764,
#    'end': 44014,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'pound',
#    'start': 44052,
#    'end': 44318,
#    'confidence': 0.77,
#    'speaker': None},
#   {'text': 'meatloaf',
#    'start': 44354,
#    'end': 44858,
#    'confidence': 0.36465,
#    'speaker': None},
#   {'text': 'that',
#    'start': 44894,
#    'end': 45058,
#    'confidence': 0.99856,
#    'speaker': None},
#   {'text': 'everybody',
#    'start': 45084,
#    'end': 45418,
#    'confidence': 0.90832,
#    'speaker': None},
#   {'text': 'here',
#    'start': 45504,
#    'end': 45754,
#    'confidence': 0.99501,
#    'speaker': None},
#   {'text': 'has',
#    'start': 45792,
#    'end': 46318,
#    'confidence': 0.99778,
#    'speaker': None},
#   {'text': 'between',
#    'start': 46464,
#    'end': 46882,
#    'confidence': 0.99927,
#    'speaker': None},
#   {'text': 'their',
#    'start': 46956,
#    'end': 47266,
#    'confidence': 0.99902,
#    'speaker': None},
#   {'text': 'ears.',
#    'start': 47328,
#    'end': 48230,
#    'confidence': 0.70802,
#    'speaker': None},
#   {'text': 'What',
#    'start': 48410,
#    'end': 48790,
#    'confidence': 0.99974,
#    'speaker': None},
#   {'text': 'is',
#    'start': 48840,
#    'end': 49018,
#    'confidence': 0.9993,
#    'speaker': None},
#   {'text': 'it',
#    'start': 49044,
#    'end': 49620,
#    'confidence': 0.96186,
#    'speaker': None},
#   {'text': 'about',
#    'start': 50070,
#    'end': 50686,
#    'confidence': 0.99988,
#    'speaker': None},
#   {'text': 'a',
#    'start': 50808,
#    'end': 51022,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'big',
#    'start': 51036,
#    'end': 51286,
#    'confidence': 0.99832,
#    'speaker': None},
#   {'text': 'brain',
#    'start': 51348,
#    'end': 51710,
#    'confidence': 0.93244,
#    'speaker': None},
#   {'text': 'that',
#    'start': 51770,
#    'end': 51958,
#    'confidence': 0.99694,
#    'speaker': None},
#   {'text': 'nature',
#    'start': 51984,
#    'end': 52490,
#    'confidence': 0.9476,
#    'speaker': None},
#   {'text': 'was',
#    'start': 52610,
#    'end': 52858,
#    'confidence': 0.98347,
#    'speaker': None},
#   {'text': 'so',
#    'start': 52884,
#    'end': 53074,
#    'confidence': 0.99412,
#    'speaker': None},
#   {'text': 'eager',
#    'start': 53112,
#    'end': 53474,
#    'confidence': 0.99822,
#    'speaker': None},
#   {'text': 'for',
#    'start': 53522,
#    'end': 53698,
#    'confidence': 0.99616,
#    'speaker': None},
#   {'text': 'everyone',
#    'start': 53724,
#    'end': 53986,
#    'confidence': 0.70534,
#    'speaker': None},
#   {'text': 'else',
#    'start': 54048,
#    'end': 54310,
#    'confidence': 0.66467,
#    'speaker': None},
#   {'text': 'to',
#    'start': 54360,
#    'end': 54538,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'have',
#    'start': 54564,
#    'end': 54754,
#    'confidence': 0.99972,
#    'speaker': None},
#   {'text': 'one?',
#    'start': 54792,
#    'end': 55390,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'Well,',
#    'start': 55560,
#    'end': 55858,
#    'confidence': 0.92548,
#    'speaker': None},
#   {'text': 'it',
#    'start': 55884,
#    'end': 56002,
#    'confidence': 0.96812,
#    'speaker': None},
#   {'text': 'turns',
#    'start': 56016,
#    'end': 56222,
#    'confidence': 0.9993,
#    'speaker': None},
#   {'text': 'out',
#    'start': 56246,
#    'end': 56398,
#    'confidence': 0.99904,
#    'speaker': None},
#   {'text': 'when',
#    'start': 56424,
#    'end': 56614,
#    'confidence': 0.99809,
#    'speaker': None},
#   {'text': 'brains',
#    'start': 56652,
#    'end': 56930,
#    'confidence': 0.9471,
#    'speaker': None},
#   {'text': 'triple',
#    'start': 56990,
#    'end': 57302,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'in',
#    'start': 57326,
#    'end': 57478,
#    'confidence': 0.99747,
#    'speaker': None},
#   {'text': 'size,',
#    'start': 57504,
#    'end': 57730,
#    'confidence': 0.99982,
#    'speaker': None},
#   {'text': 'they',
#    'start': 57780,
#    'end': 57922,
#    'confidence': 0.99771,
#    'speaker': None},
#   {'text': "don't",
#    'start': 57936,
#    'end': 58082,
#    'confidence': 0.98865,
#    'speaker': None},
#   {'text': 'just',
#    'start': 58106,
#    'end': 58258,
#    'confidence': 0.98752,
#    'speaker': None},
#   {'text': 'get',
#    'start': 58284,
#    'end': 58438,
#    'confidence': 0.99673,
#    'speaker': None},
#   {'text': 'three',
#    'start': 58464,
#    'end': 58690,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'times',
#    'start': 58740,
#    'end': 59026,
#    'confidence': 0.99816,
#    'speaker': None},
#   {'text': 'bigger.',
#    'start': 59088,
#    'end': 59522,
#    'confidence': 0.56912,
#    'speaker': None},
#   {'text': 'They',
#    'start': 59606,
#    'end': 59854,
#    'confidence': 0.99633,
#    'speaker': None},
#   {'text': 'gain',
#    'start': 59892,
#    'end': 60134,
#    'confidence': 0.99874,
#    'speaker': None},
#   {'text': 'new',
#    'start': 60182,
#    'end': 60394,
#    'confidence': 0.98,
#    'speaker': None},
#   {'text': 'structures.',
#    'start': 60432,
#    'end': 61214,
#    'confidence': 0.91202,
#    'speaker': None},
#   {'text': 'And',
#    'start': 61382,
#    'end': 61714,
#    'confidence': 0.74,
#    'speaker': None},
#   {'text': 'one',
#    'start': 61752,
#    'end': 61918,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'of',
#    'start': 61944,
#    'end': 62062,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'the',
#    'start': 62076,
#    'end': 62182,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'main',
#    'start': 62196,
#    'end': 62374,
#    'confidence': 0.99973,
#    'speaker': None},
#   {'text': 'reasons',
#    'start': 62412,
#    'end': 62726,
#    'confidence': 0.99282,
#    'speaker': None},
#   {'text': 'that',
#    'start': 62738,
#    'end': 62842,
#    'confidence': 0.95058,
#    'speaker': None},
#   {'text': 'our',
#    'start': 62856,
#    'end': 62998,
#    'confidence': 0.53566,
#    'speaker': None},
#   {'text': 'brain',
#    'start': 63024,
#    'end': 63338,
#    'confidence': 0.8085,
#    'speaker': None},
#   {'text': 'got',
#    'start': 63374,
#    'end': 63574,
#    'confidence': 0.9998,
#    'speaker': None},
#   {'text': 'so',
#    'start': 63612,
#    'end': 63814,
#    'confidence': 0.99956,
#    'speaker': None},
#   {'text': 'big',
#    'start': 63852,
#    'end': 64198,
#    'confidence': 0.99989,
#    'speaker': None},
#   {'text': 'is',
#    'start': 64284,
#    'end': 64498,
#    'confidence': 0.99802,
#    'speaker': None},
#   {'text': 'because',
#    'start': 64524,
#    'end': 64750,
#    'confidence': 0.99723,
#    'speaker': None},
#   {'text': 'it',
#    'start': 64800,
#    'end': 65086,
#    'confidence': 0.99786,
#    'speaker': None},
#   {'text': 'got',
#    'start': 65148,
#    'end': 65374,
#    'confidence': 0.99816,
#    'speaker': None},
#   {'text': 'a',
#    'start': 65412,
#    'end': 65542,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'new',
#    'start': 65556,
#    'end': 65734,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'part',
#    'start': 65772,
#    'end': 66262,
#    'confidence': 0.99458,
#    'speaker': None},
#   {'text': 'called',
#    'start': 66396,
#    'end': 66658,
#    'confidence': 0.9995,
#    'speaker': None},
#   {'text': 'the',
#    'start': 66684,
#    'end': 66838,
#    'confidence': 0.71,
#    'speaker': None},
#   {'text': 'frontal',
#    'start': 66864,
#    'end': 67202,
#    'confidence': 0.99716,
#    'speaker': None},
#   {'text': 'lobe',
#    'start': 67226,
#    'end': 67478,
#    'confidence': 0.99421,
#    'speaker': None},
#   {'text': 'and',
#    'start': 67514,
#    'end': 67678,
#    'confidence': 0.91,
#    'speaker': None},
#   {'text': 'particularly',
#    'start': 67704,
#    'end': 68378,
#    'confidence': 0.67847,
#    'speaker': None},
#   {'text': 'a',
#    'start': 68474,
#    'end': 68662,
#    'confidence': 0.9,
#    'speaker': None},
#   {'text': 'part',
#    'start': 68676,
#    'end': 68854,
#    'confidence': 0.99979,
#    'speaker': None},
#   {'text': 'called',
#    'start': 68892,
#    'end': 69022,
#    'confidence': 0.99888,
#    'speaker': None},
#   {'text': 'the',
#    'start': 69036,
#    'end': 69178,
#    'confidence': 0.51,
#    'speaker': None},
#   {'text': 'prefrontal',
#    'start': 69204,
#    'end': 69662,
#    'confidence': 0.94909,
#    'speaker': None},
#   {'text': 'cortex.',
#    'start': 69686,
#    'end': 70538,
#    'confidence': 0.69041,
#    'speaker': None},
#   {'text': 'And',
#    'start': 70694,
#    'end': 70942,
#    'confidence': 0.09,
#    'speaker': None},
#   {'text': 'what',
#    'start': 70956,
#    'end': 71062,
#    'confidence': 0.99745,
#    'speaker': None},
#   {'text': 'does',
#    'start': 71076,
#    'end': 71182,
#    'confidence': 0.6393,
#    'speaker': None},
#   {'text': 'the',
#    'start': 71196,
#    'end': 71266,
#    'confidence': 0.66,
#    'speaker': None},
#   {'text': 'prefrontal',
#    'start': 71268,
#    'end': 71702,
#    'confidence': 0.99285,
#    'speaker': None},
#   {'text': 'cortex',
#    'start': 71726,
#    'end': 72194,
#    'confidence': 0.79822,
#    'speaker': None},
#   {'text': 'do',
#    'start': 72242,
#    'end': 72454,
#    'confidence': 0.9999,
#    'speaker': None},
#   {'text': 'for',
#    'start': 72492,
#    'end': 72694,
#    'confidence': 0.99971,
#    'speaker': None},
#   {'text': 'you',
#    'start': 72732,
#    'end': 73186,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'that',
#    'start': 73308,
#    'end': 73558,
#    'confidence': 0.99908,
#    'speaker': None},
#   {'text': 'should',
#    'start': 73584,
#    'end': 73810,
#    'confidence': 0.66523,
#    'speaker': None},
#   {'text': 'justify',
#    'start': 73860,
#    'end': 74366,
#    'confidence': 0.98689,
#    'speaker': None},
#   {'text': 'the',
#    'start': 74438,
#    'end': 74674,
#    'confidence': 0.53,
#    'speaker': None},
#   {'text': 'entire',
#    'start': 74712,
#    'end': 75130,
#    'confidence': 0.99982,
#    'speaker': None},
#   {'text': 'architectural',
#    'start': 75240,
#    'end': 75998,
#    'confidence': 0.91036,
#    'speaker': None},
#   {'text': 'overhaul',
#    'start': 76034,
#    'end': 76442,
#    'confidence': 0.98879,
#    'speaker': None},
#   {'text': 'of',
#    'start': 76466,
#    'end': 76582,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'the',
#    'start': 76596,
#    'end': 76738,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'human',
#    'start': 76764,
#    'end': 77026,
#    'confidence': 0.9997,
#    'speaker': None},
#   {'text': 'skull',
#    'start': 77088,
#    'end': 77702,
#    'confidence': 0.99507,
#    'speaker': None},
#   {'text': 'in',
#    'start': 77846,
#    'end': 78082,
#    'confidence': 0.99527,
#    'speaker': None},
#   {'text': 'the',
#    'start': 78096,
#    'end': 78202,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'blink',
#    'start': 78216,
#    'end': 78530,
#    'confidence': 0.876,
#    'speaker': None},
#   {'text': 'of',
#    'start': 78590,
#    'end': 78778,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'evolutionary',
#    'start': 78804,
#    'end': 79394,
#    'confidence': 0.9834,
#    'speaker': None},
#   {'text': 'time?',
#    'start': 79442,
#    'end': 79690,
#    'confidence': 0.99809,
#    'speaker': None},
#   {'text': 'Well,',
#    'start': 79740,
#    'end': 80134,
#    'confidence': 0.95183,
#    'speaker': None},
#   {'text': 'turns',
#    'start': 80232,
#    'end': 80582,
#    'confidence': 0.99871,
#    'speaker': None},
#   {'text': 'out',
#    'start': 80606,
#    'end': 80758,
#    'confidence': 0.99952,
#    'speaker': None},
#   {'text': 'the',
#    'start': 80784,
#    'end': 80902,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'prefrontal',
#    'start': 80916,
#    'end': 81302,
#    'confidence': 0.99752,
#    'speaker': None},
#   {'text': 'cortex',
#    'start': 81326,
#    'end': 81758,
#    'confidence': 0.55397,
#    'speaker': None},
#   {'text': 'does',
#    'start': 81794,
#    'end': 82030,
#    'confidence': 0.99881,
#    'speaker': None},
#   {'text': 'lots',
#    'start': 82080,
#    'end': 82322,
#    'confidence': 0.9982,
#    'speaker': None},
#   {'text': 'of',
#    'start': 82346,
#    'end': 82462,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'things,',
#    'start': 82476,
#    'end': 82726,
#    'confidence': 0.99946,
#    'speaker': None},
#   {'text': 'but',
#    'start': 82788,
#    'end': 83014,
#    'confidence': 0.89548,
#    'speaker': None},
#   {'text': 'one',
#    'start': 83052,
#    'end': 83218,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'of',
#    'start': 83244,
#    'end': 83362,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'the',
#    'start': 83376,
#    'end': 83482,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'most',
#    'start': 83496,
#    'end': 83710,
#    'confidence': 0.99695,
#    'speaker': None},
#   {'text': 'important',
#    'start': 83760,
#    'end': 84082,
#    'confidence': 0.99976,
#    'speaker': None},
#   {'text': 'things',
#    'start': 84156,
#    'end': 84430,
#    'confidence': 0.98817,
#    'speaker': None},
#   {'text': 'it',
#    'start': 84480,
#    'end': 84658,
#    'confidence': 0.99038,
#    'speaker': None},
#   {'text': 'does',
#    'start': 84684,
#    'end': 85234,
#    'confidence': 0.99918,
#    'speaker': None},
#   {'text': 'is',
#    'start': 85392,
#    'end': 85678,
#    'confidence': 0.99598,
#    'speaker': None},
#   {'text': 'it',
#    'start': 85704,
#    'end': 85858,
#    'confidence': 0.93648,
#    'speaker': None},
#   {'text': 'is',
#    'start': 85884,
#    'end': 86038,
#    'confidence': 0.97956,
#    'speaker': None},
#   {'text': 'an',
#    'start': 86064,
#    'end': 86254,
#    'confidence': 0.99789,
#    'speaker': None},
#   {'text': 'experience',
#    'start': 86292,
#    'end': 86880,
#    'confidence': 0.99957,
#    'speaker': None},
#   {'text': 'simulator',
#    'start': 87390,
#    'end': 88454,
#    'confidence': 0.99802,
#    'speaker': None},
#   {'text': 'pilots',
#    'start': 88622,
#    'end': 89150,
#    'confidence': 0.99846,
#    'speaker': None},
#   {'text': 'practice',
#    'start': 89210,
#    'end': 89666,
#    'confidence': 0.98199,
#    'speaker': None},
#   {'text': 'in',
#    'start': 89738,
#    'end': 89938,
#    'confidence': 0.51183,
#    'speaker': None},
#   {'text': 'flight',
#    'start': 89964,
#    'end': 90290,
#    'confidence': 0.99366,
#    'speaker': None},
#   {'text': 'simulators',
#    'start': 90350,
#    'end': 91034,
#    'confidence': 0.63901,
#    'speaker': None},
#   {'text': 'so',
#    'start': 91082,
#    'end': 91222,
#    'confidence': 0.99909,
#    'speaker': None},
#   {'text': 'that',
#    'start': 91236,
#    'end': 91378,
#    'confidence': 0.98089,
#    'speaker': None},
#   {'text': 'they',
#    'start': 91404,
#    'end': 91522,
#    'confidence': 0.99966,
#    'speaker': None},
#   {'text': "don't",
#    'start': 91536,
#    'end': 91718,
#    'confidence': 0.96,
#    'speaker': None},
#   {'text': 'make',
#    'start': 91754,
#    'end': 91954,
#    'confidence': 0.99982,
#    'speaker': None},
#   {'text': 'real',
#    'start': 91992,
#    'end': 92194,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'mistakes',
#    'start': 92232,
#    'end': 92678,
#    'confidence': 0.74893,
#    'speaker': None},
#   {'text': 'in',
#    'start': 92714,
#    'end': 92878,
#    'confidence': 0.97167,
#    'speaker': None},
#   {'text': 'planes.',
#    'start': 92904,
#    'end': 93610,
#    'confidence': 0.93262,
#    'speaker': None},
#   {'text': 'Human',
#    'start': 93930,
#    'end': 94366,
#    'confidence': 0.9997,
#    'speaker': None},
#   {'text': 'beings',
#    'start': 94428,
#    'end': 94910,
#    'confidence': 0.88631,
#    'speaker': None},
#   {'text': 'have',
#    'start': 94970,
#    'end': 95158,
#    'confidence': 0.99935,
#    'speaker': None},
#   {'text': 'this',
#    'start': 95184,
#    'end': 95338,
#    'confidence': 0.9969,
#    'speaker': None},
#   {'text': 'marvelous',
#    'start': 95364,
#    'end': 95798,
#    'confidence': 0.99092,
#    'speaker': None},
#   {'text': 'adaptation',
#    'start': 95834,
#    'end': 96434,
#    'confidence': 0.18345,
#    'speaker': None},
#   {'text': 'that',
#    'start': 96482,
#    'end': 96658,
#    'confidence': 0.99104,
#    'speaker': None},
#   {'text': 'they',
#    'start': 96684,
#    'end': 96838,
#    'confidence': 0.99808,
#    'speaker': None},
#   {'text': 'can',
#    'start': 96864,
#    'end': 97018,
#    'confidence': 0.99739,
#    'speaker': None},
#   {'text': 'actually',
#    'start': 97044,
#    'end': 97450,
#    'confidence': 0.97891,
#    'speaker': None},
#   {'text': 'have',
#    'start': 97560,
#    'end': 97906,
#    'confidence': 0.93914,
#    'speaker': None},
#   {'text': 'experiences',
#    'start': 97968,
#    'end': 98978,
#    'confidence': 0.99603,
#    'speaker': None},
#   {'text': 'in',
#    'start': 99074,
#    'end': 99298,
#    'confidence': 0.99927,
#    'speaker': None},
#   {'text': 'their',
#    'start': 99324,
#    'end': 99514,
#    'confidence': 0.99944,
#    'speaker': None},
#   {'text': 'heads',
#    'start': 99552,
#    'end': 100226,
#    'confidence': 0.9953,
#    'speaker': None},
#   {'text': 'before',
#    'start': 100358,
#    'end': 100978,
#    'confidence': 0.99999,
#    'speaker': None},
#   {'text': 'they',
#    'start': 101124,
#    'end': 101434,
#    'confidence': 0.997,
#    'speaker': None},
#   {'text': 'try',
#    'start': 101472,
#    'end': 101674,
#    'confidence': 0.98501,
#    'speaker': None},
#   {'text': 'them',
#    'start': 101712,
#    'end': 101842,
#    'confidence': 0.99926,
#    'speaker': None},
#   {'text': 'out',
#    'start': 101856,
#    'end': 101962,
#    'confidence': 0.99883,
#    'speaker': None},
#   {'text': 'in',
#    'start': 101976,
#    'end': 102118,
#    'confidence': 0.64579,
#    'speaker': None},
#   {'text': 'real',
#    'start': 102144,
#    'end': 102298,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'life.',
#    'start': 102324,
#    'end': 102550,
#    'confidence': 0.71047,
#    'speaker': None},
#   {'text': 'This',
#    'start': 102600,
#    'end': 102778,
#    'confidence': 0.9988,
#    'speaker': None},
#   {'text': 'is',
#    'start': 102804,
#    'end': 102922,
#    'confidence': 0.99845,
#    'speaker': None},
#   {'text': 'a',
#    'start': 102936,
#    'end': 103006,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'trick',
#    'start': 103008,
#    'end': 103202,
#    'confidence': 0.52377,
#    'speaker': None},
#   {'text': 'that',
#    'start': 103226,
#    'end': 103378,
#    'confidence': 0.99873,
#    'speaker': None},
#   {'text': 'none',
#    'start': 103404,
#    'end': 103586,
#    'confidence': 0.99841,
#    'speaker': None},
#   {'text': 'of',
#    'start': 103598,
#    'end': 103702,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'our',
#    'start': 103716,
#    'end': 103858,
#    'confidence': 0.99929,
#    'speaker': None},
#   {'text': 'ancestors',
#    'start': 103884,
#    'end': 104414,
#    'confidence': 0.96514,
#    'speaker': None},
#   {'text': 'could',
#    'start': 104462,
#    'end': 104638,
#    'confidence': 0.98098,
#    'speaker': None},
#   {'text': 'do,',
#    'start': 104664,
#    'end': 105034,
#    'confidence': 0.99957,
#    'speaker': None},
#   {'text': 'that',
#    'start': 105132,
#    'end': 105430,
#    'confidence': 0.98593,
#    'speaker': None},
#   {'text': 'no',
#    'start': 105480,
#    'end': 105694,
#    'confidence': 0.99971,
#    'speaker': None},
#   {'text': 'other',
#    'start': 105732,
#    'end': 105970,
#    'confidence': 0.99987,
#    'speaker': None},
#   {'text': 'animal',
#    'start': 106020,
#    'end': 106430,
#    'confidence': 0.99932,
#    'speaker': None},
#   {'text': 'can',
#    'start': 106490,
#    'end': 106714,
#    'confidence': 0.99968,
#    'speaker': None},
#   {'text': 'do',
#    'start': 106752,
#    'end': 106990,
#    'confidence': 0.99929,
#    'speaker': None},
#   {'text': 'quite',
#    'start': 107040,
#    'end': 107290,
#    'confidence': 0.99945,
#    'speaker': None},
#   {'text': 'like',
#    'start': 107340,
#    'end': 107590,
#    'confidence': 0.99672,
#    'speaker': None},
#   {'text': 'we',
#    'start': 107640,
#    'end': 107854,
#    'confidence': 0.99913,
#    'speaker': None},
#   {'text': 'can.',
#    'start': 107892,
#    'end': 108238,
#    'confidence': 0.99923,
#    'speaker': None},
#   {'text': "It's",
#    'start': 108324,
#    'end': 108602,
#    'confidence': 0.63691,
#    'speaker': None},
#   {'text': 'a',
#    'start': 108626,
#    'end': 108742,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'marvelous',
#    'start': 108756,
#    'end': 109214,
#    'confidence': 0.98145,
#    'speaker': None},
#   {'text': 'adaptation.',
#    'start': 109262,
#    'end': 109910,
#    'confidence': 0.58895,
#    'speaker': None},
#   {'text': "It's",
#    'start': 109970,
#    'end': 110258,
#    'confidence': 0.98397,
#    'speaker': None},
#   {'text': 'up',
#    'start': 110294,
#    'end': 110458,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'there',
#    'start': 110484,
#    'end': 110674,
#    'confidence': 0.99967,
#    'speaker': None},
#   {'text': 'with',
#    'start': 110712,
#    'end': 110878,
#    'confidence': 0.99981,
#    'speaker': None},
#   {'text': 'opposable',
#    'start': 110904,
#    'end': 111434,
#    'confidence': 0.9851,
#    'speaker': None},
#   {'text': 'thumbs',
#    'start': 111482,
#    'end': 111854,
#    'confidence': 0.97911,
#    'speaker': None},
#   {'text': 'and',
#    'start': 111902,
#    'end': 112078,
#    'confidence': 0.97,
#    'speaker': None},
#   {'text': 'standing',
#    'start': 112104,
#    'end': 112478,
#    'confidence': 0.99664,
#    'speaker': None},
#   {'text': 'upright',
#    'start': 112514,
#    'end': 112814,
#    'confidence': 0.93286,
#    'speaker': None},
#   {'text': 'in',
#    'start': 112862,
#    'end': 113074,
#    'confidence': 0.98998,
#    'speaker': None},
#   {'text': 'language',
#    'start': 113112,
#    'end': 113690,
#    'confidence': 0.91177,
#    'speaker': None},
#   {'text': 'as',
#    'start': 113810,
#    'end': 114058,
#    'confidence': 0.95503,
#    'speaker': None},
#   {'text': 'one',
#    'start': 114084,
#    'end': 114202,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'of',
#    'start': 114216,
#    'end': 114286,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'the',
#    'start': 114288,
#    'end': 114382,
#    'confidence': 0.97,
#    'speaker': None},
#   {'text': 'things',
#    'start': 114396,
#    'end': 114610,
#    'confidence': 0.62847,
#    'speaker': None},
#   {'text': 'that',
#    'start': 114660,
#    'end': 114838,
#    'confidence': 0.99935,
#    'speaker': None},
#   {'text': 'got',
#    'start': 114864,
#    'end': 115018,
#    'confidence': 0.99923,
#    'speaker': None},
#   {'text': 'our',
#    'start': 115044,
#    'end': 115486,
#    'confidence': 0.99617,
#    'speaker': None},
#   {'text': 'species',
#    'start': 115608,
#    'end': 116186,
#    'confidence': 0.9071,
#    'speaker': None},
#   {'text': 'out',
#    'start': 116258,
#    'end': 116422,
#    'confidence': 0.99972,
#    'speaker': None},
#   {'text': 'of',
#    'start': 116436,
#    'end': 116506,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'the',
#    'start': 116508,
#    'end': 116602,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'trees',
#    'start': 116616,
#    'end': 116894,
#    'confidence': 0.90948,
#    'speaker': None},
#   {'text': 'and',
#    'start': 116942,
#    'end': 117226,
#    'confidence': 0.64,
#    'speaker': None},
#   {'text': 'into',
#    'start': 117288,
#    'end': 117514,
#    'confidence': 0.79812,
#    'speaker': None},
#   {'text': 'the',
#    'start': 117552,
#    'end': 117718,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'shopping',
#    'start': 117744,
#    'end': 118022,
#    'confidence': 0.99786,
#    'speaker': None},
#   {'text': 'mall.',
#    'start': 118046,
#    'end': 118690,
#    'confidence': 0.5711,
#    'speaker': None},
#   {'text': 'Now,',
#    'start': 119010,
#    'end': 119760,
#    'confidence': 0.93093,
#    'speaker': None},
#   {'text': 'all',
#    'start': 121290,
#    'end': 121618,
#    'confidence': 0.90965,
#    'speaker': None},
#   {'text': 'of',
#    'start': 121644,
#    'end': 121762,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'you',
#    'start': 121776,
#    'end': 121918,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'have',
#    'start': 121944,
#    'end': 122134,
#    'confidence': 0.99729,
#    'speaker': None},
#   {'text': 'done',
#    'start': 122172,
#    'end': 122338,
#    'confidence': 0.99993,
#    'speaker': None},
#   {'text': 'this.',
#    'start': 122364,
#    'end': 122590,
#    'confidence': 0.99868,
#    'speaker': None},
#   {'text': 'I',
#    'start': 122640,
#    'end': 122746,
#    'confidence': 0.67,
#    'speaker': None},
#   {'text': 'mean,',
#    'start': 122748,
#    'end': 123166,
#    'confidence': 0.99395,
#    'speaker': None},
#   {'text': 'Ben',
#    'start': 123288,
#    'end': 123578,
#    'confidence': 0.98438,
#    'speaker': None},
#   {'text': 'and',
#    'start': 123614,
#    'end': 123742,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': "Jerry's",
#    'start': 123756,
#    'end': 124178,
#    'confidence': 0.47072,
#    'speaker': None},
#   {'text': "doesn't",
#    'start': 124214,
#    'end': 124514,
#    'confidence': 0.54538,
#    'speaker': None},
#   {'text': 'have',
#    'start': 124562,
#    'end': 124810,
#    'confidence': 0.99957,
#    'speaker': None},
#   {'text': 'liver',
#    'start': 124860,
#    'end': 125102,
#    'confidence': 0.64857,
#    'speaker': None},
#   {'text': 'in',
#    'start': 125126,
#    'end': 125278,
#    'confidence': 0.67595,
#    'speaker': None},
#   {'text': 'onion',
#    'start': 125304,
#    'end': 125570,
#    'confidence': 0.83118,
#    'speaker': None},
#   {'text': 'ice',
#    'start': 125630,
#    'end': 125882,
#    'confidence': 0.99726,
#    'speaker': None},
#   {'text': 'cream,',
#    'start': 125906,
#    'end': 126374,
#    'confidence': 0.97786,
#    'speaker': None},
#   {'text': 'and',
#    'start': 126482,
#    'end': 126682,
#    'confidence': 0.9,
#    'speaker': None},
#   {'text': "it's",
#    'start': 126696,
#    'end': 126902,
#    'confidence': 0.98716,
#    'speaker': None},
#   {'text': 'not',
#    'start': 126926,
#    'end': 127114,
#    'confidence': 0.99973,
#    'speaker': None},
#   {'text': 'because',
#    'start': 127152,
#    'end': 127462,
#    'confidence': 0.99937,
#    'speaker': None},
#   {'text': 'they',
#    'start': 127536,
#    'end': 127702,
#    'confidence': 0.87343,
#    'speaker': None},
#   {'text': 'whipped',
#    'start': 127716,
#    'end': 127982,
#    'confidence': 0.98031,
#    'speaker': None},
#   {'text': 'some',
#    'start': 128006,
#    'end': 128194,
#    'confidence': 0.97536,
#    'speaker': None},
#   {'text': 'up,',
#    'start': 128232,
#    'end': 128470,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'tried',
#    'start': 128520,
#    'end': 128770,
#    'confidence': 0.99212,
#    'speaker': None},
#   {'text': 'it',
#    'start': 128820,
#    'end': 128962,
#    'confidence': 0.99728,
#    'speaker': None},
#   {'text': 'and',
#    'start': 128976,
#    'end': 129082,
#    'confidence': 0.98,
#    'speaker': None},
#   {'text': 'went',
#    'start': 129096,
#    'end': 129310,
#    'confidence': 0.99923,
#    'speaker': None},
#   {'text': 'Yuck.',
#    'start': 129360,
#    'end': 129854,
#    'confidence': 0.98361,
#    'speaker': None},
#   {'text': "It's",
#    'start': 129962,
#    'end': 130262,
#    'confidence': 0.98233,
#    'speaker': None},
#   {'text': 'because',
#    'start': 130286,
#    'end': 130860,
#    'confidence': 0.99863,
#    'speaker': None},
#   {'text': 'without',
#    'start': 131430,
#    'end': 131830,
#    'confidence': 0.99836,
#    'speaker': None},
#   {'text': 'leaving',
#    'start': 131880,
#    'end': 132098,
#    'confidence': 0.99917,
#    'speaker': None},
#   {'text': 'your',
#    'start': 132134,
#    'end': 132298,
#    'confidence': 0.99585,
#    'speaker': None},
#   {'text': 'armchair,',
#    'start': 132324,
#    'end': 132938,
#    'confidence': 0.95934,
#    'speaker': None},
#   {'text': 'you',
#    'start': 133034,
#    'end': 133294,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'can',
#    'start': 133332,
#    'end': 133570,
#    'confidence': 0.99962,
#    'speaker': None},
#   {'text': 'simulate',
#    'start': 133620,
#    'end': 134174,
#    'confidence': 0.99928,
#    'speaker': None},
#   {'text': 'that',
#    'start': 134222,
#    'end': 134434,
#    'confidence': 0.99934,
#    'speaker': None},
#   {'text': 'flavor',
#    'start': 134472,
#    'end': 134918,
#    'confidence': 0.96765,
#    'speaker': None},
#   {'text': 'and',
#    'start': 135014,
#    'end': 135238,
#    'confidence': 0.7,
#    'speaker': None},
#   {'text': 'say',
#    'start': 135264,
#    'end': 135490,
#    'confidence': 0.99706,
#    'speaker': None},
#   {'text': 'Yuck',
#    'start': 135540,
#    'end': 135902,
#    'confidence': 0.85077,
#    'speaker': None},
#   {'text': 'before',
#    'start': 135986,
#    'end': 136522,
#    'confidence': 0.99986,
#    'speaker': None},
#   {'text': 'you',
#    'start': 136656,
#    'end': 136918,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'make',
#    'start': 136944,
#    'end': 137134,
#    'confidence': 0.99965,
#    'speaker': None},
#   {'text': 'it.',
#    'start': 137172,
#    'end': 137760,
#    'confidence': 0.99956,
#    'speaker': None},
#   {'text': "Let's",
#    'start': 139530,
#    'end': 139922,
#    'confidence': 0.98744,
#    'speaker': None},
#   {'text': 'see',
#    'start': 139946,
#    'end': 140170,
#    'confidence': 0.99984,
#    'speaker': None},
#   {'text': 'how',
#    'start': 140220,
#    'end': 140434,
#    'confidence': 0.99988,
#    'speaker': None},
#   {'text': 'your',
#    'start': 140472,
#    'end': 140674,
#    'confidence': 0.99055,
#    'speaker': None},
#   {'text': 'experience',
#    'start': 140712,
#    'end': 141094,
#    'confidence': 0.99989,
#    'speaker': None},
#   {'text': 'simulators',
#    'start': 141192,
#    'end': 141878,
#    'confidence': 0.57134,
#    'speaker': None},
#   {'text': 'are',
#    'start': 141914,
#    'end': 142078,
#    'confidence': 0.99961,
#    'speaker': None},
#   {'text': 'working.',
#    'start': 142104,
#    'end': 142330,
#    'confidence': 0.99969,
#    'speaker': None},
#   {'text': "Let's",
#    'start': 142380,
#    'end': 142622,
#    'confidence': 0.95244,
#    'speaker': None},
#   {'text': 'just',
#    'start': 142646,
#    'end': 142762,
#    'confidence': 0.99856,
#    'speaker': None},
#   {'text': 'run',
#    'start': 142776,
#    'end': 142918,
#    'confidence': 0.99174,
#    'speaker': None},
#   {'text': 'a',
#    'start': 142944,
#    'end': 143062,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'quick',
#    'start': 143076,
#    'end': 143290,
#    'confidence': 0.99978,
#    'speaker': None},
#   {'text': 'diagnostic',
#    'start': 143340,
#    'end': 144074,
#    'confidence': 0.50158,
#    'speaker': None},
#   {'text': 'before',
#    'start': 144122,
#    'end': 144370,
#    'confidence': 0.99994,
#    'speaker': None},
#   {'text': 'I',
#    'start': 144420,
#    'end': 144562,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'PROCEED',
#    'start': 144576,
#    'end': 144914,
#    'confidence': 0.98227,
#    'speaker': None},
#   {'text': 'with',
#    'start': 144962,
#    'end': 145102,
#    'confidence': 0.99985,
#    'speaker': None},
#   {'text': 'the',
#    'start': 145116,
#    'end': 145258,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'rest',
#    'start': 145284,
#    'end': 145438,
#    'confidence': 0.99997,
#    'speaker': None},
#   {'text': 'of',
#    'start': 145464,
#    'end': 145546,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'the',
#    'start': 145548,
#    'end': 145678,
#    'confidence': 0.98,
#    'speaker': None},
#   {'text': 'talk.',
#    'start': 145704,
#    'end': 146182,
#    'confidence': 0.99908,
#    'speaker': None},
#   {'text': "Here's",
#    'start': 146316,
#    'end': 146714,
#    'confidence': 0.63403,
#    'speaker': None},
#   {'text': 'two',
#    'start': 146762,
#    'end': 147010,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'different',
#    'start': 147060,
#    'end': 147382,
#    'confidence': 0.99988,
#    'speaker': None},
#   {'text': 'futures',
#    'start': 147456,
#    'end': 148034,
#    'confidence': 0.84456,
#    'speaker': None},
#   {'text': 'that',
#    'start': 148082,
#    'end': 148258,
#    'confidence': 0.99862,
#    'speaker': None},
#   {'text': 'I',
#    'start': 148284,
#    'end': 148438,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'invite',
#    'start': 148464,
#    'end': 148718,
#    'confidence': 0.97273,
#    'speaker': None},
#   {'text': 'you',
#    'start': 148754,
#    'end': 148918,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'to',
#    'start': 148944,
#    'end': 149134,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'contemplate,',
#    'start': 149172,
#    'end': 149858,
#    'confidence': 0.58582,
#    'speaker': None},
#   {'text': 'and',
#    'start': 149954,
#    'end': 150178,
#    'confidence': 0.93,
#    'speaker': None},
#   {'text': 'you',
#    'start': 150204,
#    'end': 150358,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'can',
#    'start': 150384,
#    'end': 150538,
#    'confidence': 0.9991,
#    'speaker': None},
#   {'text': 'try',
#    'start': 150564,
#    'end': 150718,
#    'confidence': 0.99893,
#    'speaker': None},
#   {'text': 'to',
#    'start': 150744,
#    'end': 150898,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'simulate',
#    'start': 150924,
#    'end': 151358,
#    'confidence': 0.62285,
#    'speaker': None},
#   {'text': 'them',
#    'start': 151394,
#    'end': 151522,
#    'confidence': 0.99856,
#    'speaker': None},
#   {'text': 'and',
#    'start': 151536,
#    'end': 151642,
#    'confidence': 0.99,
#    'speaker': None},
#   {'text': 'tell',
#    'start': 151656,
#    'end': 151798,
#    'confidence': 0.9741,
#    'speaker': None},
#   {'text': 'me',
#    'start': 151824,
#    'end': 151978,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'which',
#    'start': 152004,
#    'end': 152158,
#    'confidence': 0.99789,
#    'speaker': None},
#   {'text': 'one',
#    'start': 152184,
#    'end': 152338,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'you',
#    'start': 152364,
#    'end': 152554,
#    'confidence': 0.54,
#    'speaker': None},
#   {'text': 'think',
#    'start': 152592,
#    'end': 152758,
#    'confidence': 0.99807,
#    'speaker': None},
#   {'text': 'you',
#    'start': 152784,
#    'end': 152938,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'might',
#    'start': 152964,
#    'end': 153154,
#    'confidence': 0.99952,
#    'speaker': None},
#   {'text': 'prefer.',
#    'start': 153192,
#    'end': 153890,
#    'confidence': 0.93023,
#    'speaker': None},
#   {'text': 'One',
#    'start': 154070,
#    'end': 154378,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'of',
#    'start': 154404,
#    'end': 154522,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'them',
#    'start': 154536,
#    'end': 154822,
#    'confidence': 0.99433,
#    'speaker': None},
#   {'text': 'is',
#    'start': 154896,
#    'end': 155350,
#    'confidence': 0.9993,
#    'speaker': None},
#   {'text': 'winning',
#    'start': 155460,
#    'end': 155834,
#    'confidence': 0.91488,
#    'speaker': None},
#   {'text': 'the',
#    'start': 155882,
#    'end': 156058,
#    'confidence': 0.93,
#    'speaker': None},
#   {'text': 'lottery.',
#    'start': 156084,
#    'end': 156650,
#    'confidence': 0.54819,
#    'speaker': None},
#   {'text': 'This',
#    'start': 156710,
#    'end': 156862,
#    'confidence': 0.99893,
#    'speaker': None},
#   {'text': 'is',
#    'start': 156876,
#    'end': 157018,
#    'confidence': 0.94079,
#    'speaker': None},
#   {'text': 'about',
#    'start': 157044,
#    'end': 157486,
#    'confidence': 0.99738,
#    'speaker': None},
#   {'text': '$314,000,000,',
#    'start': 157608,
#    'end': 158002,
#    'confidence': 0.98,
#    'speaker': None},
#   {'text': 'and',
#    'start': 158016,
#    'end': 159778,
#    'confidence': 0.94,
#    'speaker': None},
#   {'text': 'the',
#    'start': 159804,
#    'end': 159958,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'other',
#    'start': 159984,
#    'end': 160282,
#    'confidence': 0.99428,
#    'speaker': None},
#   {'text': 'is',
#    'start': 160356,
#    'end': 160702,
#    'confidence': 0.9977,
#    'speaker': None},
#   {'text': 'becoming',
#    'start': 160776,
#    'end': 161234,
#    'confidence': 0.68571,
#    'speaker': None},
#   {'text': 'paraplegic.',
#    'start': 161282,
#    'end': 162430,
#    'confidence': 0.95481,
#    'speaker': None},
#   {'text': 'So',
#    'start': 163110,
#    'end': 163438,
#    'confidence': 0.82916,
#    'speaker': None},
#   {'text': 'just',
#    'start': 163464,
#    'end': 163654,
#    'confidence': 0.9912,
#    'speaker': None},
#   {'text': 'give',
#    'start': 163692,
#    'end': 163822,
#    'confidence': 0.99056,
#    'speaker': None},
#   {'text': 'it',
#    'start': 163836,
#    'end': 163942,
#    'confidence': 0.99719,
#    'speaker': None},
#   {'text': 'a',
#    'start': 163956,
#    'end': 164062,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'moment',
#    'start': 164076,
#    'end': 164326,
#    'confidence': 0.99993,
#    'speaker': None},
#   {'text': 'of',
#    'start': 164388,
#    'end': 164578,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'thought.',
# ...
#    'speaker': None},
#   {'text': 'They went around campus.',
#    'start': 935534,
#    'end': 936374,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8640554547309875,
#    'speaker': None},
#   {'text': 'They took twelve pictures of their favorite professors in their dorm room and their dog.',
#    'start': 936422,
#    'end': 941170,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.5452674627304077,
#    'speaker': None},
#   {'text': 'And all the other things they wanted to have Harvard memories of.',
#    'start': 941220,
#    'end': 944014,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7187817096710205,
#    'speaker': None},
#   {'text': 'They bring us the camera, we make up a contact sheet.',
#    'start': 944172,
#    'end': 946610,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8848762512207031,
#    'speaker': None},
#   {'text': 'They figure out which are the two best pictures.',
#    'start': 946670,
#    'end': 948506,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.6439218521118164,
#    'speaker': None},
#   {'text': 'And we now spend 6 hours teaching them about dark rooms.',
#    'start': 948578,
#    'end': 951134,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6959435939788818,
#    'speaker': None},
#   {'text': 'And they blow two of them up.',
#    'start': 951182,
#    'end': 952522,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.6815465688705444,
#    'speaker': None},
#   {'text': 'And they have two gorgeous eight by ten glossies of meaningful things to them.',
#    'start': 952536,
#    'end': 955978,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.9112706184387207,
#    'speaker': None},
#   {'text': 'And we say, which one would you like to give up?',
#    'start': 956004,
#    'end': 958800,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.770539402961731,
#    'speaker': None},
#   {'text': 'I have to give one up.',
#    'start': 959250,
#    'end': 960178,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.6119917035102844,
#    'speaker': None},
#   {'text': 'Oh, yes.',
#    'start': 960204,
#    'end': 960670,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.6818090081214905,
#    'speaker': None},
#   {'text': 'We need one as evidence of the class project.',
#    'start': 960720,
#    'end': 963694,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8506559133529663,
#    'speaker': None},
#   {'text': 'So you have to give me one.',
#    'start': 963852,
#    'end': 965230,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7053062915802002,
#    'speaker': None},
#   {'text': 'You have to make a choice.',
#    'start': 965280,
#    'end': 966434,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7000063061714172,
#    'speaker': None},
#   {'text': 'You get to keep one, and I get to keep one.',
#    'start': 966542,
#    'end': 969226,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7496398091316223,
#    'speaker': None},
#   {'text': 'Now, there are two conditions in this experiment.',
#    'start': 969288,
#    'end': 972374,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8154264092445374,
#    'speaker': None},
#   {'text': 'In one case, the students are told.',
#    'start': 972422,
#    'end': 974446,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7254443764686584,
#    'speaker': None},
#   {'text': 'But, you know, if you want to change your mind.',
#    'start': 974568,
#    'end': 976690,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8134282231330872,
#    'speaker': None},
#   {'text': "I'll always have the other one here.",
#    'start': 976800,
#    'end': 978610,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5853759050369263,
#    'speaker': None},
#   {'text': 'And in the next four days before I actually mail it to headquarters.',
#    'start': 978780,
#    'end': 982810,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8206282258033752,
#    'speaker': None},
#   {'text': "I'll be glad to headquarters.",
#    'start': 983250,
#    'end': 985550,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.8487883806228638,
#    'speaker': None},
#   {'text': "I'll be glad to swap it out with you.",
#    'start': 985670,
#    'end': 987898,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.7745527625083923,
#    'speaker': None},
#   {'text': "In fact, I'll come to your dorm room and just give me an email.",
#    'start': 987924,
#    'end': 991150,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7732638120651245,
#    'speaker': None},
#   {'text': "Better yet, I'll check with you.",
#    'start': 991200,
#    'end': 993106,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7421508431434631,
#    'speaker': None},
#   {'text': 'You ever want to change your mind?',
#    'start': 993228,
#    'end': 994414,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7330207824707031,
#    'speaker': None},
#   {'text': "It's totally returnable.",
#    'start': 994452,
#    'end': 995894,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.8489217162132263,
#    'speaker': None},
#   {'text': 'The other half of the students are told exactly the opposite.',
#    'start': 996002,
#    'end': 998822,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.6702118515968323,
#    'speaker': None},
#   {'text': 'Make your choice.',
#    'start': 998966,
#    'end': 999902,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6947603225708008,
#    'speaker': None},
#   {'text': 'And by the way, the mail is going out.',
#    'start': 999986,
#    'end': 1001914,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6721721887588501,
#    'speaker': None},
#   {'text': 'Gosh in two minutes to England.',
#    'start': 1001952,
#    'end': 1003766,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7232348322868347,
#    'speaker': None},
#   {'text': 'Your picture will be winging its way over the Atlantic.',
#    'start': 1003838,
#    'end': 1005902,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6118170619010925,
#    'speaker': None},
#   {'text': 'You will never see it again.',
#    'start': 1005926,
#    'end': 1007638,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.7372211813926697,
#    'speaker': None},
#   {'text': "Now, half of the students in each of these conditions are asked to make predictions about how much they're going to come to like the picture that they keep and the picture they leave behind.",
#    'start': 1007724,
#    'end': 1017370,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7867568135261536,
#    'speaker': None},
#   {'text': 'Other students are just sent back to their little dorm rooms and they are measured over the next three to six days on their liking satisfaction with the pictures.',
#    'start': 1017540,
#    'end': 1025750,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8885347843170166,
#    'speaker': None},
#   {'text': 'Look at what we find.',
#    'start': 1025810,
#    'end': 1026610,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.814015805721283,
#    'speaker': None},
#   {'text': "First of all, here's what students think is going to happen.",
#    'start': 1026660,
#    'end': 1030294,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8275154829025269,
#    'speaker': None},
#   {'text': "They think they're going to maybe come to like the picture they chose a little more than the one they left behind.",
#    'start': 1030452,
#    'end': 1036642,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6224311590194702,
#    'speaker': None},
#   {'text': 'But these are not statistically significant differences.',
#    'start': 1036836,
#    'end': 1040258,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5174519419670105,
#    'speaker': None},
#   {'text': "It's a very small increase and it doesn't much matter whether they were in the reversible or irreversible condition.",
#    'start': 1040414,
#    'end': 1046246,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.693048357963562,
#    'speaker': None},
#   {'text': 'Wrong.',
#    'start': 1046318,
#    'end': 1046662,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.7284254431724548,
#    'speaker': None},
#   {'text': 'Oh, bad simulators.',
#    'start': 1046736,
#    'end': 1048922,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.849703848361969,
#    'speaker': None},
#   {'text': "Because here's what's really happening both right before the swap and five days later, people who are stuck with that picture, who have no choice, who can never change their mind like it a lot, and people who are deliberating.",
#    'start': 1049006,
#    'end': 1064078,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.47745123505592346,
#    'speaker': None},
#   {'text': 'Should I return it?',
#    'start': 1064174,
#    'end': 1064998,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8878404498100281,
#    'speaker': None},
#   {'text': 'Have I gotten the right one?',
#    'start': 1065024,
#    'end': 1065898,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7920397520065308,
#    'speaker': None},
#   {'text': "Maybe this isn't the good one, maybe I left the good one have killed themselves.",
#    'start': 1065924,
#    'end': 1069414,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.7563356757164001,
#    'speaker': None},
#   {'text': "They don't like their picture and in fact, even after the opportunity to swap has expired, they still don't like their picture.",
#    'start': 1069572,
#    'end': 1076590,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.9403409957885742,
#    'speaker': None},
#   {'text': 'Why?',
#    'start': 1077150,
#    'end': 1077766,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6120102405548096,
#    'speaker': None},
#   {'text': 'Because the irreversible condition is not conducive to the synthesis of happiness.',
#    'start': 1077888,
#    'end': 1083310,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.8073945641517639,
#    'speaker': None},
#   {'text': "So here's the final piece of this experiment.",
#    'start': 1084050,
#    'end': 1086890,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.8870625495910645,
#    'speaker': None},
#   {'text': "We bring in a whole new group of naive Harvard students and we say we're doing a photography course and we can do it one of two ways we could do it so that when you take the two pictures, you'd have four days to change your mind or we're doing another course where you take the two pictures and you make up your mind right away and you can never change it.",
#    'start': 1087010,
#    'end': 1105582,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.701824426651001,
#    'speaker': None},
#   {'text': 'Which course would you like to be in?',
#    'start': 1105596,
#    'end': 1107480,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.9130136966705322,
#    'speaker': None},
#   {'text': '66% of the students, two thirds prefer to be in the course where they have the opportunity to change their mind.',
#    'start': 1108830,
#    'end': 1115650,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6228158473968506,
#    'speaker': None},
#   {'text': 'Hello.',
#    'start': 1115700,
#    'end': 1116274,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5208580493927002,
#    'speaker': None},
#   {'text': '66% of the students choose to be in the course in which they will ultimately be deeply dissatisfied with the picture because they do not know the conditions under which synthetic happiness grows.',
#    'start': 1116432,
#    'end': 1130050,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.9083933234214783,
#    'speaker': None},
#   {'text': "The Bard said everything best, of course, and he's making my point here, but he's making it hyperbolically.",
#    'start': 1130610,
#    'end': 1137638,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5409960150718689,
#    'speaker': None},
#   {'text': 'Tis nothing good or bad, but thinking makes it so.',
#    'start': 1137674,
#    'end': 1140790,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.5794692039489746,
#    'speaker': None},
#   {'text': "It's nice poetry, but that can't exactly be right.",
#    'start': 1140960,
#    'end': 1144150,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.514756977558136,
#    'speaker': None},
#   {'text': 'Is there really nothing good or bad?',
#    'start': 1144260,
#    'end': 1146274,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5531082153320312,
#    'speaker': None},
#   {'text': 'Is it really the case that gallbladder surgery and a trip to Paris are just the same thing?',
#    'start': 1146372,
#    'end': 1152000,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5374744534492493,
#    'speaker': None},
#   {'text': 'That seems like a one question IQ test.',
#    'start': 1153170,
#    'end': 1156582,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6963542103767395,
#    'speaker': None},
#   {'text': "They can't be exactly the same in more turgid prose, but closer to the truth was the father of modern capitalism, Adam Smith, and he said this.",
#    'start': 1156776,
#    'end': 1165270,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7923126220703125,
#    'speaker': None},
#   {'text': 'This is worth contemplating.',
#    'start': 1165320,
#    'end': 1167086,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.6713351607322693,
#    'speaker': None},
#   {'text': 'The great source of both the misery and disorders of human life seems to arise from overrating the difference between one permanent situation and another.',
#    'start': 1167218,
#    'end': 1176838,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.9522654414176941,
#    'speaker': None},
#   {'text': 'Some of these situations may no doubt deserve to be preferred to others but none of them can deserve to be pursued with that passionate ardor which drives us to violate the rules either of prudence or of justice or to corrupt the future tranquility of our minds either by shame from the remembrance of our own folly or by remorse for the horror of our own injustice.',
#    'start': 1176984,
#    'end': 1202666,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.7348092794418335,
#    'speaker': None},
#   {'text': 'In other words, yes, some things are better than others.',
#    'start': 1202738,
#    'end': 1207294,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.733045220375061,
#    'speaker': None},
#   {'text': 'We should have preferences that lead us into one future over another.',
#    'start': 1207452,
#    'end': 1212540,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.7737143039703369,
#    'speaker': None},
#   {'text': 'But when those preferences drive us too hard and too fast because we have overrated the difference between these futures, we are at risk.',
#    'start': 1212870,
#    'end': 1223054,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.8123980164527893,
#    'speaker': None},
#   {'text': 'When our ambition is bounded, it leads us to work joyfully.',
#    'start': 1223102,
#    'end': 1226786,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.8499420881271362,
#    'speaker': None},
#   {'text': 'When our ambition is unbounded, it leads us to lie, to cheat, to steal, to hurt others, to sacrifice things of real value.',
#    'start': 1226858,
#    'end': 1235122,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.8895330429077148,
#    'speaker': None},
#   {'text': "When our fears are bounded, we're prudent, we're cautious, we're thoughtful.",
#    'start': 1235196,
#    'end': 1239974,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.6191657781600952,
#    'speaker': None},
#   {'text': "When our fears are unbounded and overblown, we're reckless and we're cowardly.",
#    'start': 1240022,
#    'end': 1246286,
#    'sentiment': 'NEGATIVE',
#    'confidence': 0.8592686057090759,
#    'speaker': None},
#   {'text': 'The lesson I want to leave you with from these data is that our longings and our worries are both to some degree overblown because we have within us the capacity to manufacture the very commodity we are constantly chasing when we choose experience.',
#    'start': 1246478,
#    'end': 1264260,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5582270622253418,
#    'speaker': None},
#   {'text': 'Thank you.',
#    'start': 1264590,
#    'end': 1265520,
#    'sentiment': 'POSITIVE',
#    'confidence': 0.8529649376869202,
#    'speaker': None},
#   {'text': 'That was Dan Ann Gilbert recorded at Ted 2004 in Monterey, California, February 2004.',
#    'start': 1270450,
#    'end': 1276250,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.9427764415740967,
#    'speaker': None},
#   {'text': 'For more information on Ted, visit TED.com.',
#    'start': 1276360,
#    'end': 1278920,
#    'sentiment': 'NEUTRAL',
#    'confidence': 0.5580204725265503,
#    'speaker': None}],
#  'entity_detection': False,
#  'entities': None}

# %%
data = {}
for sentence in res.json().get('sentiment_analysis_results'):
    if sentence.get('sentiment') in data:
        data[sentence.get('sentiment')] +=1
    else:
        data[sentence.get('sentiment')] = 1
    
data['total'] = len(res.json().get('sentiment_analysis_results'))
print(data)
# Out:
# {'NEUTRAL': 180, 'POSITIVE': 57, 'NEGATIVE': 64, 'total': 301}

# %%
import matplotlib.pyplot as plt
names = list(data.keys())
values = list(data.values())
c = ['gray', 'green', 'red', 'orange']
plt.bar(range(len(data)), values, tick_label=names, color=c)
plt.show()
